# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot

import numpy

# %matplotlib inline

# %%
cos_sig = thinkdsp.CosSignal(freq=440)

# %%
cos_sig.plot()
thinkplot.config(xlabel='time (s)', legend=False)

# %%
wave = cos_sig.make_wave(duration=0.5, framerate=11025)

# %%
wave.apodize()
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum = wave.make_spectrum()

# %%
spectrum.plot()
thinkplot.config(xlabel='frequency (Hz)', legend=False)

# %%
saw_sig = thinkdsp.SawtoothSignal(freq=440)
saw_sig.plot()

# %%
saw_wave = saw_sig.make_wave(duration=0.5)
saw_wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
saw_wave.make_spectrum().plot()

# %%
mixer_speed_1_raw = thinkdsp.read_wave('mixer_speed_1.wav')
mixer_speed_1_raw.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(mixer_speed_1_raw.ts,mixer_speed_1_raw.ys)
plt.show()

# %%
mixer_speed_1_raw.ts
# Out:
# array([0.00000000e+00, 2.08333333e-05, 4.16666667e-05, ...,
#        2.73993750e+00, 2.73995833e+00, 2.73997917e+00])

# %%
mixer_speed_1_raw.plot()

# %%
mixer_speed_1_spectrum = mixer_speed_1_raw.make_spectrum()
mixer_speed_1_spectrum.plot()

# %%
mixer_speed_1_spectogram  = mixer_speed_1_raw.make_spectrogram(seg_length=1024)
mixer_speed_1_spectogram.plot(high=5000)

# %%
mixer_speed_2_raw = thinkdsp.read_wave('mixer_speed_2.wav')
mixer_speed_2_raw.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mixer_speed_2_raw.plot()

# %%
mixer_speed_2_raw.ts
# Out:
# array([0.00000000e+00, 2.08333333e-05, 4.16666667e-05, ...,
#        3.43993750e+00, 3.43995833e+00, 3.43997917e+00])

# %%
mixer_speed_2_spectrum = mixer_speed_2_raw.make_spectrum()
mixer_speed_2_spectrum.plot()

# %%
mixer_speed_2_spectogram  = mixer_speed_2_raw.make_spectrogram(seg_length=1024)
mixer_speed_2_spectogram.plot(high=5000)

# %%
mixer_speed_3_raw = thinkdsp.read_wave('mixer_speed_3.wav')
mixer_speed_3_raw.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mixer_speed_3_spectrum = mixer_speed_3_raw.make_spectrum()
mixer_speed_3_spectrum.plot()

# %%
mixer_speed_3_spectogram  = mixer_speed_3_raw.make_spectrogram(seg_length=1024)
mixer_speed_3_spectogram.plot(high=5000)

# %%
mixer_speed_1_raw_data1 = mixer_speed_1_raw.segment(0, 0.5)
mixer_speed_1_raw_data2 = mixer_speed_1_raw.segment(0.5, 0.5)
mixer_speed_1_raw_data3 = mixer_speed_1_raw.segment(1, 0.5)
mixer_speed_1_raw_data4 = mixer_speed_1_raw.segment(1.5, 0.5)

# %%
mixer_speed_1_raw_data1.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mixer_speed_1_raw_data2.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mixer_speed_1_raw_data3.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mixer_speed_1_raw_data4.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
mixer_speed_1_raw_data1_spectrum = mixer_speed_1_raw_data1.make_spectrum()
mixer_speed_1_raw_data1_spectrum.plot()

# %%
mixer_speed_1_raw_data2_spectrum = mixer_speed_1_raw_data2.make_spectrum()
mixer_speed_1_raw_data2_spectrum.plot()

# %%
mixer_speed_1_raw_data3_spectrum = mixer_speed_1_raw_data3.make_spectrum()
mixer_speed_1_raw_data3_spectrum.plot()

# %%
mixer_speed_1_raw_data4_spectrum = mixer_speed_1_raw_data4.make_spectrum()
mixer_speed_1_raw_data4_spectrum.plot()

# %%
import matplotlib.pyplot as plt
plt.plot(mixer_speed_1_raw_data4_spectrum.fs,mixer_speed_1_raw_data4_spectrum.amps)
plt.show()

# %%
mixer_speed_1_raw_data4_spectrum.fs
# Out:
# array([0.0000e+00, 2.0000e+00, 4.0000e+00, ..., 2.3996e+04, 2.3998e+04,
#        2.4000e+04])

# %%
mixer_speed_2_raw_data1 = mixer_speed_2_raw.segment(0, 0.5)
mixer_speed_2_raw_data2 = mixer_speed_2_raw.segment(0.5, 0.5)
mixer_speed_2_raw_data3 = mixer_speed_2_raw.segment(1, 0.5)
mixer_speed_2_raw_data4 = mixer_speed_2_raw.segment(1.5, 0.5)
mixer_speed_2_raw_data5 = mixer_speed_2_raw.segment(2, 0.5)
mixer_speed_2_raw_data6 = mixer_speed_2_raw.segment(2.5, 0.5)

# %%
mixer_speed_1_raw.ts
# Out:
# array([0.00000000e+00, 2.08333333e-05, 4.16666667e-05, ...,
#        2.73993750e+00, 2.73995833e+00, 2.73997917e+00])

# %%
mixer_speed_2_raw.ts
# Out:
# array([0.00000000e+00, 2.08333333e-05, 4.16666667e-05, ...,
#        3.43993750e+00, 3.43995833e+00, 3.43997917e+00])

# %%
mixer_speed_3_raw.ts
# Out:
# array([0.00000000e+00, 2.08333333e-05, 4.16666667e-05, ...,
#        2.37993750e+00, 2.37995833e+00, 2.37997917e+00])

# %%
plt.plot(mixer_speed_2_raw_data2.ys)
plt.show()

# %%
import numpy as np
#plt.plot(mixer_speed_2_raw_data2.ys)
plt.plot(np.random.normal(np.max(mixer_speed_2_raw_data2.ys)*0.01))
plt.show()

# %%
(np.random.normal((mixer_speed_2_raw_data2.ys)*.01))
# Out:
# array([-2.19267155, -0.28345203, -1.05020439, ..., -1.04304756,
#        -0.18591024, -0.36538528])

# %%
plt.plot(mixer_speed_1_raw_data4_spectrum.amps)
plt.plot(mixer_speed_1_raw_data4_spectrum.amps + np.random.normal(np.mean(mixer_speed_1_raw_data4_spectrum.amps)*0.01))
plt.show()
